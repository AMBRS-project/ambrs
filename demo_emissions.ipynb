# %% [markdown]
# ### Overview
#
# The AMBRS tools facilitate intercomparison of aerosol box models. The core components include (1) the CMake-based *ambuilder* for consistent model building, (2) the Python-based *amdriver* for automated generation of unified numerical experiments, and (3) the Python-based *pyparticle* package for standardization of model output and downstream analysis.
#
# This notebook describes the steps to build, run, and analyze the AMBRS models.

# %% [markdown]
# ### Step 1: Build supported models via AMBuilder
#
# Build all box models via [AMbuilder](https://github.com/AMBRS-project/ambuilder)
#
# Install additional AMBRS dependencies via:
# ```
# pip install -r requirements.txt
# ```

# %% [markdown]
# ### Step 2: Run comparable simulation experiments with the AMBRS driver

# %%
# -----------------------------------------------------------
# Import modules
# -----------------------------------------------------------
import os
import logging
from math import log10
from pathlib import Path

import numpy as np
import scipy.stats as stats

import ambrs
from pathlib import Path

# -----------------------------------------------------------
# Configure simulations
# -----------------------------------------------------------

n = 5        # number of ensemble members
n_part = 10000  # PartMC particles per run

dt = 60      # timestep [s]
nstep = 60   # 60 min run

p0 = 101325  # reference pressure [Pa]
h0 = 500     # reference height [m]

# -----------------------------------------------------------
# Make directories for simulation output
# -----------------------------------------------------------
ensemble_name = str(int(dt*nstep/60)) + "min_" + str(n_part) + "particles_withEmissions"
repo_root = Path.cwd().resolve()
root_dir =  repo_root / "runs" 
ensemble_dir =  root_dir / ensemble_name
partmc_dir = os.path.join(ensemble_dir, "partmc_runs")
mam4_dir = os.path.join(ensemble_dir, "mam4_runs")

for d in [root_dir, ensemble_dir, partmc_dir, mam4_dir]:
    os.makedirs(d, exist_ok=True)


# -----------------------------------------------------------
# Define species
# -----------------------------------------------------------
so4 = ambrs.AerosolSpecies("SO4", molar_mass=96., density=1800., hygroscopicity=0.65)
nh4 = ambrs.AerosolSpecies("NH4", molar_mass=18., density=1800., hygroscopicity=0.65)
pom = ambrs.AerosolSpecies("OC", molar_mass=12.01, density=1000., hygroscopicity=0.001, aliases="POM")
soa = ambrs.AerosolSpecies("MSA", molar_mass=40., density=2600., hygroscopicity=0.53, aliases="SOA")
bc  = ambrs.AerosolSpecies("BC",  molar_mass=12.01, density=1800., hygroscopicity=0.)
dst = ambrs.AerosolSpecies("OIN", molar_mass=135.065, density=2600., hygroscopicity=0.1, aliases="DST")
na  = ambrs.AerosolSpecies("Na",  molar_mass=23., density=2200., hygroscopicity=0.53, aliases="NCL")
cl  = ambrs.AerosolSpecies("Cl",  molar_mass=35.5, density=2200., hygroscopicity=0.53, aliases="NCL")
ncl = na
h2o = ambrs.AerosolSpecies("H2O", molar_mass=18., density=1000., ions_in_soln=1)

so2   = ambrs.GasSpecies("SO2", molar_mass=64.07)
h2so4 = ambrs.GasSpecies("H2SO4", molar_mass=98.079)

# -----------------------------------------------------------
# Define aerosol processes
# -----------------------------------------------------------
processes = ambrs.AerosolProcesses(
    coagulation=True,
    condensation=True,
    do_camp_chem=False,
    # FIXME: add do emissions here? (override ppe specification?)
)

# -----------------------------------------------------------
# Ensemble specification
# -----------------------------------------------------------

# MAM4 GMDs and GSDs taken from MAM_box_model/box_model_utils/rad_constituents.f90
spec = ambrs.EnsembleSpecification(
    name=ensemble_name,
    aerosols=(so4, nh4, pom, soa, bc, dst, ncl, h2o),
    gases=(so2, h2so4),
    size=ambrs.AerosolModalSizeDistribution(modes=[
        ambrs.AerosolModeDistribution(
            name="accumulation",
            species=[so4, pom, soa, bc, dst, ncl],
            number=stats.uniform(1e7, 1e10),
            # number=stats.loguniform(1e7, 1e10, loc=0, scale=1),
            geom_mean_diam=stats.rv_discrete(values=([1.1e-7], [1.])),
            log10_geom_std_dev=log10(1.8), 
            mass_fractions=[
                stats.rv_discrete(values=([1.], [1.])),  # SO4
                stats.rv_discrete(values=([0.], [1.])),  # POM 
                stats.rv_discrete(values=([0.], [1.])),  # SOA
                stats.rv_discrete(values=([0.], [1.])),  # BC 
                stats.rv_discrete(values=([0.], [1.])),  # DST
                stats.rv_discrete(values=([0.], [1.])),  # NCL
            ],
        ),
        ambrs.AerosolModeDistribution(
            name="aitken",
            species=[so4, soa, ncl],
            number=stats.uniform(1e7, 1e11),
            # number=stats.loguniform(1e7, 1e11, loc=0, scale=1),
            # number=stats.rv_discrete(values=([0.], [1.])), # used to zero out all but one mode for debugging
            geom_mean_diam=stats.rv_discrete(values=([2.6e-8], [1.])),
            log10_geom_std_dev=log10(1.6), 
            mass_fractions=[
                stats.rv_discrete(values=([1.], [1.])),  # SO4
                stats.rv_discrete(values=([0.], [1.])),  # SOA
                stats.rv_discrete(values=([0.], [1.])),  # NCL
            ],
        ),
        ambrs.AerosolModeDistribution(
            name="coarse",
            species=[dst, ncl, so4, bc, pom, soa],
            number=stats.uniform(1e6, 1e7),
            # number=stats.loguniform(1e6, 1e7, loc=0, scale=1),
            # number=stats.rv_discrete(values=([0.], [1.])), # used to zero out all but one mode for debugging
            geom_mean_diam=stats.rv_discrete(values=([2e-6], [1.])),
            log10_geom_std_dev=log10(1.6), # 1.6 s correct (and 1.8 is incorrect) (I think)
            mass_fractions=[
                stats.rv_discrete(values=([0.], [1.])),
                stats.rv_discrete(values=([0.], [1.])),
                stats.rv_discrete(values=([1.], [1.])),  # SO4
                stats.rv_discrete(values=([0.], [1.])),
                stats.rv_discrete(values=([0.], [1.])), # POM
                stats.rv_discrete(values=([0.], [1.])),
            ],
        ),
        ambrs.AerosolModeDistribution(
            name="primary carbon",
            species=[pom, bc],
            number=stats.rv_discrete(values=([0.], [1.])), # primary carbon mode zeroed out for now
            geom_mean_diam=stats.loguniform(1e-8, 5e-8),
            log10_geom_std_dev=log10(1.8),
            mass_fractions=[
                stats.rv_discrete(values=([1.], [1.])),  # POM
                stats.rv_discrete(values=([0.], [1.])),  # BC
            ],
        ),
    ]),
    # concentrations specified in mol/mol-air
    gas_concs=tuple([stats.rv_discrete(values=([0.], [1.])),stats.uniform(1e-10, 1e-8)]), # set SO2 concentration to zero, H2SO4 only
    # gas_concs=tuple([stats.uniform(0, 1e-8), stats.rv_discrete(values=([0.], [1.]))]), # set SO2 concentration to zero, H2SO4 only
    flux=stats.uniform(1e-11, 1e-8), # not doing anything
    relative_humidity=stats.rv_discrete(values=([0.], [1.])),
    temperature=stats.uniform(240, 70),
    pressure=p0,
    height=h0,
    aerosol_emissions=[
        ambrs.AerosolEmissions(
            time=0,
            rate=1.0,
            size=ambrs.AerosolModalSizeDistribution(modes=[
                ambrs.AerosolModeDistribution(
                    name="emission_mode",
                    species=[so4, pom, bc],
                    number=stats.uniform(1e6, 1e9),
                    geom_mean_diam=stats.loguniform(1e-8, 5e-7),
                    log10_geom_std_dev=log10(1.8),
                    mass_fractions=[
                        stats.rv_discrete(values=([0.5], [1.])),  # SO4
                        stats.rv_discrete(values=([0.4], [1.])),  # POM
                        stats.rv_discrete(values=([0.1], [1.])),  # BC
                    ],
                ),
            ]),
        ),
    ]
)

# -----------------------------------------------------------
# Create ensemble
# -----------------------------------------------------------
ensemble = ambrs.lhs(specification=spec, n=n)
scenario_names = [str(ii).zfill(1) for ii in range(1, len(ensemble.flux)+1)]


# # -----------------------------------------------------------
# # Run MAM4
# # -----------------------------------------------------------
# mam4 = ambrs.mam4.AerosolModel(processes=processes)
# mam4_inputs = mam4.create_inputs(ensemble=ensemble, dt=dt, nstep=nstep)
# mam4_runner = ambrs.PoolRunner(
#     model=mam4,
#     executable="mam4",
#     root=mam4_dir,
#     num_processes=1,
# )
# mam4_runner.run(mam4_inputs)

# -----------------------------------------------------------
# Run PartMC
# -----------------------------------------------------------
partmc = ambrs.partmc.AerosolModel(
    processes=processes,
    run_type="particle",
    n_part=n_part,
    n_repeat=1,
)
partmc_inputs = partmc.create_inputs(ensemble=ensemble, dt=dt, nstep=nstep)
partmc_runner = ambrs.PoolRunner(
    model=partmc,
    executable="partmc",
    root=partmc_dir,
    num_processes=1,
)
partmc_runner.run(partmc_inputs)

# %% [markdown]
# ### Step 3: Analyze and vizualize model output with pyparticle

# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec as mgs  # <-- for GridSpecFromSubplotSpec

# scenarios = ["1","2","3","4","5"]   # rows

fig = plt.figure(constrained_layout=True, figsize=(12, 7))

scenario_names = None
if scenario_names == None:
    n_scenarios = ensemble.__len__()
else:
    n_scenarios = len(scenario_names)
# Make a 4-column OUTER grid: [DSD init | DSD after 30 min | CCN  after 30 min | SCAT  after 30 min]

outer = fig.add_gridspec(
    nrows=n_scenarios, ncols=4, 
    hspace=0.1, wspace=0.6
)

# Make CHILD grids for each block using GridSpecFromSubplotSpec
gs_dsd_init  = mgs.GridSpecFromSubplotSpec(n_scenarios, 1, subplot_spec=outer[:, 0])
gs_dsd  = mgs.GridSpecFromSubplotSpec(n_scenarios, 1, subplot_spec=outer[:, 1])
gs_ccn  = mgs.GridSpecFromSubplotSpec(n_scenarios, 1,              subplot_spec=outer[:, 2])
gs_scat = mgs.GridSpecFromSubplotSpec(n_scenarios, 1,              subplot_spec=outer[:, 3])

final_timestep = 31
# ---- render the left block (dN/dlnD at initialization)
ambrs.viz.render_dNdlnD_grid(
    gs_dsd_init,
    ensemble=ensemble,
    scenario_names=scenario_names,
    timesteps=[1],          # 2 columns on the left
    partmc_dir=partmc_dir,
    # mam4_dir=mam4_dir, # defaults to None if not provided --> no read
    D_range=(2e-9, 5e-7),
    N_bins=1000,
    normalize=True,
    method="kde",
    legend_loc=None
)

# ---- render the second block (dN/dlnD after 30 min)
ambrs.viz.render_dNdlnD_grid(
    gs_dsd,
    ensemble=ensemble,
    scenario_names=scenario_names,
    timesteps=[final_timestep],          # 2 columns on the left
    partmc_dir=partmc_dir,
    # mam4_dir=mam4_dir, # defaults to None if not provided --> no read
    D_range=(2e-9, 5e-7),
    N_bins=1000,
    normalize=True,
    method="kde",
    legend_loc=None,
    sharey=False,
)
all_dsd_axes = fig.axes
y_max = max([ax.get_ylim()[1] for ax in all_dsd_axes])
for ax in all_dsd_axes:
    ax.set_ylim(0, y_max)

# # ---- render the third block (CCN fraction after 30 min)
ambrs.viz.render_frac_ccn_grid(gs_ccn, #fig=fig, 
                        ensemble=ensemble, scenario_names=scenario_names,
                        timesteps=[final_timestep], 
                        partmc_dir=partmc_dir, 
                        # mam4_dir=mam4_dir, # defaults to None if not provided --> no read
                        legend_loc=None,)
all_axes = fig.axes
for ax in all_axes[-n_scenarios:]:
    ax.set_ylim(0, 1.0)

# ---- render the fourth block (scattering cross section after 30 min)
ambrs.viz.render_bscat_grid(gs_scat, #fig=fig, 
                     ensemble=ensemble, scenario_names=scenario_names,
                     timesteps=[final_timestep], 
                     partmc_dir=partmc_dir, 
                     # mam4_dir=mam4_dir, # defaults to None if not provided --> no read
                     legend_loc=None)

all_axes = fig.axes
y_max = max([ax.get_ylim()[1] for ax in all_axes[-n_scenarios:]])
cols = ambrs.viz._scenario_colors(n_rows=n_scenarios)
for ii,ax in enumerate(all_axes[-n_scenarios:]):
    # ax.set_ylim(0, y_max)
    ambrs.viz._add_row_label(ax, 'scenario ' + str(ii+1), color=cols[ii])

plt.savefig('ensemble_summary.png', dpi=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 28
#      26 final_timestep = 31
#      27 # ---- render the left block (dN/dlnD at initialization)
# ---> 28 ambrs.viz.render_dNdlnD_grid(
#      29     gs_dsd_init,
#      30     ensemble=ensemble,
#      31     scenario_names=scenario_names,
#      32     timesteps=[1],          # 2 columns on the left
#      33     partmc_dir=partmc_dir,
#      34     mam4_dir=mam4_dir,
#      35     D_range=(2e-9, 5e-7),
#      36     N_bins=1000,
#      37     normalize=True,
#      38     method="kde",
#      39     legend_loc=None
#      40 )
#      42 # ---- render the second block (dN/dlnD after 30 min)
#      43 ambrs.viz.render_dNdlnD_grid(
#      44     gs_dsd,
#      45     ensemble=ensemble,
#    (...)     55     sharey=False,
#      56 )
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Code/ambrs/ambrs/viz.py:233, in render_dNdlnD_grid(gs, ensemble, scenario_names, timesteps, partmc_dir, mam4_dir, D_range, N_bins, normalize, method, legend_loc, row_colors, xscale, yscale, spec_modifications, sharex, sharey, color)
#     220 def render_dNdlnD_grid(
#     221     gs, *, ensemble, scenario_names, timesteps, partmc_dir, mam4_dir,
#     222     D_range=(1e-9, 1e-6), N_bins=50, normalize=True, method="kde",
#    (...)    226     sharex=True, sharey=False,
#     227     color=None):
#     228     """
#     229     Render a grid of aerosol size distributions (dNdlnD) for multiple scenarios and timesteps.
#     230     Each subplot shows the size distribution for a given scenario and timestep, using data from PartMC and MAM4.
#     231     Options include normalization, binning, and visualization settings.
#     232     """
# --> 233     return render_partmc_and_mam4_variable_grid(
#     234         gs, # GridSpec
#     235         varname = 'dNdlnD',
#     236         var_cfg = make_dNdlnD_cfg(
#     237             D_range=D_range, N_bins=N_bins, normalize=normalize, method=method),
#     238         ensemble = ensemble,
#     239         scenario_names = scenario_names,
#     240         timesteps = timesteps,
#     241         partmc_dir = partmc_dir,
#     242         mam4_dir = mam4_dir,
#     243         legend_loc = legend_loc,
#     244         row_colors = row_colors,
#     245         xscale = xscale,
#     246         yscale = yscale,
#     247         species_modifications = spec_modifications, # modify aerosol species during post-processing (e.g., assume BrC rather than non-absorbing OC)
#     248         sharex = sharex,
#     249         sharey = sharey,
#     250         color = color,
#     251         )
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Code/ambrs/ambrs/viz.py:146, in render_partmc_and_mam4_variable_grid(gs, varname, var_cfg, ensemble, timesteps, partmc_dir, mam4_dir, scenario_names, legend_loc, row_colors, xscale, yscale, species_modifications, sharex, sharey, color)
#     140 ax = fig.add_subplot(
#     141     gs[i_row, i_col],
#     142     sharex=axes[i_row-1,i_col] if sharex and i_row > 0 else None,
#     143     sharey=axes[i_row-1,i_col] if sharey and i_row > 0 else None)
#     144 axes[i_row, i_col] = ax
# --> 146 partmc_output = partmc.retrieve_model_state(
#     147     scenario_name=scenario_name,
#     148     scenario=ensemble.member(int(scenario_name)-1),
#     149     timestep=timestep,
#     150     repeat_num=1, # fixme: hardcoded for single repeat
#     151     species_modifications=species_modifications,
#     152     ensemble_output_dir=partmc_dir,
#     153 )
#     154 mam4_output = mam4.retrieve_model_state(
#     155     scenario_name=scenario_name,
#     156     scenario=ensemble.member(int(scenario_name)-1),
#    (...)    159     ensemble_output_dir=mam4_dir,
#     160 )
#     162 series = (
#     163     ("partmc", partmc_output.particle_population, "PartMC"),
#     164     ("mam4",   mam4_output.particle_population,   "MAM4"),
#     165 )
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Code/ambrs/ambrs/partmc.py:564, in retrieve_model_state(scenario_name, scenario, timestep, repeat_num, species_modifications, ensemble_output_dir)
#     556 partmc_dir = ensemble_output_dir + '/' + scenario_name
#     557 partmc_population_cfg = {
#     558     'type':'partmc',
#     559     'partmc_dir': partmc_dir,
#     560     'timestep':timestep,
#     561     'repeat':repeat_num, # number of PartMC repeat, if run multiple times
#     562     'species_modifications':species_modifications}
# --> 564 particle_population = build_population(partmc_population_cfg)
#     566 ncfilename = get_ncfile(
#     567     scenario_name, timestep,
#     568     ensemble_output_dir=ensemble_output_dir,
#     569     repeat_num=repeat_num)
#     570 currnc = Dataset(partmc_dir + '/out/' + ncfilename)
#
# File ~/miniforge3/envs/ambrs_nocamp/lib/python3.12/site-packages/part2pop/population/builder.py:30, in build_population(config)
#      28 def build_population(config):
#      29     """Convenience: build and return a population for given config."""
# ---> 30     return PopulationBuilder(config).build()
#
# File ~/miniforge3/envs/ambrs_nocamp/lib/python3.12/site-packages/part2pop/population/builder.py:25, in PopulationBuilder.build(self)
#      23     raise ValueError(f"Unknown population type: {type_name}")
#      24 cls = types[type_name]
# ---> 25 return cls(self.config)
#
# File ~/miniforge3/envs/ambrs_nocamp/lib/python3.12/site-packages/part2pop/population/factory/partmc.py:29, in build(config)
#      26 suppress_warning = config.get('suppress_warning', True)
#      27 add_mixing_ratios = config.get('add_mixing_ratios', True)
# ---> 29 partmc_filepath = get_ncfile(partmc_dir / 'out', timestep, repeat)
#      30 currnc = netCDF4.Dataset(partmc_filepath)
#      33 aero_spec_names = currnc.variables['aero_species'].names.split(',')
#
# File ~/miniforge3/envs/ambrs_nocamp/lib/python3.12/site-packages/part2pop/population/factory/partmc.py:98, in get_ncfile(partmc_output_dir, timestep, repeat)
#      96     raise FileNotFoundError(f"PartMC output directory {partmc_output_dir} does not exist.")
#      97 for root, dirs, files in os.walk(partmc_output_dir):
# ---> 98     f = files[0]
#      99 if f.startswith('urban_plume_wc_'):
#     100     preface_string = 'urban_plume_wc_'
#
# IndexError: list index out of range
