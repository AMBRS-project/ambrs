# %%
import numpy as np
import pandas as pd

# %%
Bs = \
{
    "constant" : [ -4.26938E+02, 2.89223E-01, 4.42057E-03, 2.92846E-01 ],
    "carbon" : [ -4.11248E+02, 8.96919E-01, -2.48607E-03, 1.40312E-01 ],
    "carboxylic acid" : [ -7.98796E+02, -1.09436E+00, 5.24132E-03, -2.28040E-01 ],
    "non-aromatic ring" : [ -8.72770E+01, 1.78059E+00, -3.07187E-03, -1.04341E-01 ],
    "aldehyde" : [ -7.29501E+02, 9.86017E-01, -2.92664E-03, 1.78077E-01 ],
    "C=C" : [ 5.73335E+00, 1.69764E-02, -6.28957E-04, 7.55434E-03 ],
    "ketone" : [ -1.37456E+01, 5.23486E-01, 5.50298E-04, -2.76950E-01 ]
} # from Table 5, https://doi.org/10.5194/acp-8-2773-2008
B = pd.DataFrame(Bs)
print(B['constant'] + 9*B['carbon'] + 2*B['carboxylic acid'] + B['non-aromatic ring']) # pinic acid
# print(B['constant'] + 18*B['carbon'] + B['carboxylic acid']) # octadecanoic (stearic) acid
# print(B['constant'] + 10*B['carbon'] + B['non-aromatic ring'] + B['C=C'] + B['carboxylic acid'] + B['aldehyde']) # scheme 2(d), https://doi.org/10.1016/j.fuel.2023.130306
# print(B['constant'] + 10*B['carbon'] + 2*B['C=C'] + B['ketone'] + B['carboxylic acid']) # scheme 2(c), https://doi.org/10.1016/j.fuel.2023.130306
# Out:
# 0   -5813.039000
# 1       7.953364
# 2      -0.010543
# 3       0.995233
# dtype: float64

# %%
np.log10(0.001/760)
# Out:
# np.float64(-5.880813592280791)
